# %%
# importing necesasary libraries
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('/content/IBM Attrition Data.csv')
data.head(2)
# Out:
#    Age Attrition              Department  DistanceFromHome  Education  \
# 0   41       Yes                   Sales                 1          2
# 1   49        No  Research & Development                 8          1
#
#   EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 0  Life Sciences                        2                4        Single
# 1  Life Sciences                        3                2       Married
#
#    MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# 0           5993                   8                1               6
# 1           5130                   1                3              10

# %%
data.shape
# Out:
# (1470, 13)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'Department', 'DistanceFromHome', 'Education',
#        'EducationField', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'WorkLifeBalance', 'YearsAtCompany'],
#       dtype='object')

# %%
#missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   Department               1470 non-null   object
#  3   DistanceFromHome         1470 non-null   int64
#  4   Education                1470 non-null   int64
#  5   EducationField           1470 non-null   object
#  6   EnvironmentSatisfaction  1470 non-null   int64
#  7   JobSatisfaction          1470 non-null   int64
#  8   MaritalStatus            1470 non-null   object
#  9   MonthlyIncome            1470 non-null   int64
#  10  NumCompaniesWorked       1470 non-null   int64
#  11  WorkLifeBalance          1470 non-null   int64
#  12  YearsAtCompany           1470 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 149.4+ KB

# %%
data.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# WorkLifeBalance            0
# YearsAtCompany             0
# dtype: int64

# %%
data.corr()
# Out:
# <ipython-input-7-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                               Age  DistanceFromHome  Education  \
# Age                      1.000000         -0.001686   0.208034
# DistanceFromHome        -0.001686          1.000000   0.021042
# Education                0.208034          0.021042   1.000000
# EnvironmentSatisfaction  0.010146         -0.016075  -0.027128
# JobSatisfaction         -0.004892         -0.003669  -0.011296
# MonthlyIncome            0.497855         -0.017014   0.094961
# NumCompaniesWorked       0.299635         -0.029251   0.126317
# WorkLifeBalance         -0.021490         -0.026556   0.009819
# YearsAtCompany           0.311309          0.009508   0.069114
#
#                          EnvironmentSatisfaction  JobSatisfaction  \
# ...

# %%
data.describe()
# Out:
#                Age  DistanceFromHome    Education  EnvironmentSatisfaction  \
# count  1470.000000       1470.000000  1470.000000              1470.000000
# mean     36.923810          9.192517     2.912925                 2.721769
# std       9.135373          8.106864     1.024165                 1.093082
# min      18.000000          1.000000     1.000000                 1.000000
# 25%      30.000000          2.000000     2.000000                 2.000000
# 50%      36.000000          7.000000     3.000000                 3.000000
# 75%      43.000000         14.000000     4.000000                 4.000000
# max      60.000000         29.000000     5.000000                 4.000000
#
#        JobSatisfaction  MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  \
# count      1470.000000    1470.000000         1470.000000      1470.000000
# mean          2.728571    6502.931293            2.693197         2.761224
# ...

# %%
sns.kdeplot(data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# #Attrition By Age

# %%
print(data[(data['Attrition'] == 'Yes')].groupby('Age')['Age'].count().sort_values(ascending=False))

plt.figure(figsize=(14,6), dpi=80)
sns.countplot(data=data, x='Age', hue='Attrition', order = data['Age'].value_counts().index, palette='seismic_r').set_title
('Attrition by Age');

#data['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
#plt.show()
# Out:
# Age
# 31    18
# 29    18
# 28    14
# 33    12
# 26    12
# 32    11
# 35    10
# 30     9
# 34     9
# 24     7
# 19     6
# 36     6
# 37     6
# 39     6
# 41     6
# 25     6
# 44     6
# 21     6
# 20     6
# 50     5
# 40     5
# 58     5
# 22     5
# 18     4
# 23     4
# 46     4
# 56     3
# 55     3
# 47     3
# 27     3
# 52     3
# 51     2
# 53     2
# 38     2
# 49     2
# 45     2
# 43     2
# 42     2
# 48     2
# Name: Age, dtype: int64

# %%
data['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
#print(data[(data['Attrition'] == 'Yes')].groupby('Age')['Age'].count().sort_values(ascending=False))

plt.figure(figsize=(14,6), dpi=80)
sns.scatterplot(data=data, x="Age",y="Department", hue="Attrition").set_title('Attrition by Age');

# %%
#Explore data by left employees
print(data.groupby('Attrition')['Attrition'].count())

plt.figure(figsize=(5,4), dpi=80)
sns.countplot(data=data, x='Attrition', palette='seismic_r');
# Out:
# Attrition
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
data['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# Attrition by department
print(data[(data['Attrition'] == 'Yes')].groupby('Department')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5), dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='Department', palette='cubehelix', 
              order = data['Department'].value_counts().index).set_title('Attrition by Department');
# Out:
# Department
# Research & Development    133
# Sales                      92
# Human Resources            12
# Name: Attrition, dtype: int64

# %%
data['Department'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
#Attrition by Department
data[(data['Attrition'] == 'Yes')].groupby('Department')['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# Attrition by age group
agerange = []
for age in data["Age"]:
    if age >= 18 and age < 24:
        agerange.append("18-24")
    elif age >= 25 and age < 31:
        agerange.append("25-31")
    elif age >= 32 and age < 38:
        agerange.append("32-38")
    elif age >= 39 and age < 45:
        agerange.append("39-45")
    elif age >= 46 and age < 52:
        agerange.append("46-52")
    elif age >= 53 and age < 59:
        agerange.append("53-59")
    else:
        agerange.append("60-66")
       
data["AgeRange"] = agerange
print(data[(data['Attrition'] == 'Yes')].groupby('AgeRange')['AgeRange'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5), dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='AgeRange', palette='cubehelix').set_title('Attrition by Age Group');
# Out:
# AgeRange
# 25-31    62
# 32-38    54
# 60-66    32
# 18-24    31
# 39-45    27
# 46-52    18
# 53-59    13
# Name: AgeRange, dtype: int64

# %%
agerange = []
for age in data["Age"]:
    if age >= 18 and age < 24:
        agerange.append("18-24")
    elif age >= 25 and age < 31:
        agerange.append("25-31")
    elif age >= 32 and age < 38:
        agerange.append("32-38")
    elif age >= 39 and age < 45:
        agerange.append("39-45")
    elif age >= 46 and age < 52:
        agerange.append("46-52")
    elif age >= 53 and age < 59:
        agerange.append("53-59")
    else:
        agerange.append("60-66")
       
data["AgeRange"] = agerange
print(data[(data['Attrition'] == 'Yes')].groupby('AgeRange')['AgeRange'].count().sort_values(ascending=False))

data['AgeRange'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# AgeRange
# 25-31    62
# 32-38    54
# 60-66    32
# 18-24    31
# 39-45    27
# 46-52    18
# 53-59    13
# Name: AgeRange, dtype: int64
# <Axes: ylabel='AgeRange'>

# %%
# Attrition by education
print(data[(data['Attrition'] == 'Yes')].groupby('Education')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5),dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='Education', 
              order=data['Education'].value_counts().index, palette='cubehelix').set_title('Attrition by Education');
# Out:
# Education
# 3    99
# 4    58
# 2    44
# 1    31
# 5     5
# Name: Attrition, dtype: int64

# %%
data['Education'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
#Attrition by Education pie chart
data[(data['Attrition'] == 'Yes')].groupby('Education')['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
#Attrition by Education Field
print(data[(data['Attrition'] == 'Yes')].groupby('EducationField')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5),dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='EducationField', 
              order=data['EducationField'].value_counts().index, palette='cubehelix').set_title('Attrition by EducationField');
# Out:
# EducationField
# Life Sciences       89
# Medical             63
# Marketing           35
# Technical Degree    32
# Other               11
# Human Resources      7
# Name: Attrition, dtype: int64

# %%
#Attrition by Education Field pie chart
data[(data['Attrition'] == 'Yes')].groupby('EducationField')['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
#Attrition by Department
print(data[(data['Attrition'] == 'Yes')].groupby('Department')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5),dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='Department', 
              order=data['Department'].value_counts().index, palette='cubehelix').set_title('Attrition by Department');
# Out:
# Department
# Research & Development    133
# Sales                      92
# Human Resources            12
# Name: Attrition, dtype: int64

# %%
# Attrition by marital status
print(data[(data['Attrition'] == 'Yes')].groupby('MaritalStatus')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5),dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='MaritalStatus', 
              order=data['MaritalStatus'].value_counts().index, palette='cubehelix').set_title('Attrition by MaritalStatus');
# Out:
# MaritalStatus
# Single      120
# Married      84
# Divorced     33
# Name: Attrition, dtype: int64

# %%
#Attrition by Marital status pie chart
data[(data['Attrition'] == 'Yes')].groupby('MaritalStatus')['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# Attrition by Environment Satisfaction
print(data[(data['Attrition'] == 'Yes')].groupby('EnvironmentSatisfaction')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5),dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='EnvironmentSatisfaction', 
              order=data['EnvironmentSatisfaction'].value_counts().index, palette='cubehelix').set_title('Attrition by EnvironmentSatisfaction');
# Out:
# EnvironmentSatisfaction
# 1    72
# 3    62
# 4    60
# 2    43
# Name: Attrition, dtype: int64

# %%
#Attrition by Environment satisfaction pie chart
data[(data['Attrition'] == 'Yes')].groupby('EnvironmentSatisfaction')['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# Attrition by Job Satisfaction
print(data[(data['Attrition'] == 'Yes')].groupby('JobSatisfaction')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5),dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='JobSatisfaction', 
              order=data['JobSatisfaction'].value_counts().index, palette='cubehelix').set_title('Attrition by JobSatisfaction');
# Out:
# JobSatisfaction
# 3    73
# 1    66
# 4    52
# 2    46
# Name: Attrition, dtype: int64

# %%
#Attrition by Job satisfaction pie chart
data[(data['Attrition'] == 'Yes')].groupby('JobSatisfaction')['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# Attrition by Experience
print(data[(data['Attrition'] == 'Yes')].groupby('YearsAtCompany')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5),dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='YearsAtCompany', 
              order=data['YearsAtCompany'].value_counts().index, palette='cubehelix').set_title('Attrition by YearsAtCompany');
# Out:
# YearsAtCompany
# 1     59
# 2     27
# 5     21
# 3     20
# 4     19
# 10    18
# 0     16
# 7     11
# 8      9
# 6      9
# 9      8
# 11     2
# 13     2
# 14     2
# 22     1
# 33     1
# 32     1
# 31     1
# 24     1
# 23     1
# 15     1
# 21     1
# 20     1
# 19     1
# 18     1
# 17     1
# 16     1
# 40     1
# Name: Attrition, dtype: int64

# %%
#Attrition by Job Years at company pie chart
data[(data['Attrition'] == 'Yes')].groupby('YearsAtCompany')['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
#Attrition by Num Companies Worked
print(data[(data['Attrition'] == 'Yes')].groupby('NumCompaniesWorked')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5),dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='NumCompaniesWorked', 
              order=data['NumCompaniesWorked'].value_counts().index, palette='cubehelix').set_title('Attrition by YearsAtCompany');
# Out:
# NumCompaniesWorked
# 1    98
# 0    23
# 4    17
# 7    17
# 2    16
# 3    16
# 5    16
# 6    16
# 9    12
# 8     6
# Name: Attrition, dtype: int64

# %%
#Attrition by Job Num of companies worked pie chart
data[(data['Attrition'] == 'Yes')].groupby('NumCompaniesWorked')['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
#Attrition by Salary
#print(data[(data['Attrition'] == 'Yes')].groupby('MonthlyIncome'<5000)['Attrition'].count().sort_values(ascending=False))

#plt.figure(figsize=(8,5),dpi=80)
#sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='MonthlyIncome', 
              #order=data['MonthlyIncome'<5000].value_counts().index, palette='cubehelix').set_title('Attrition by MonthlyIncome');
#(data['MonthlyIncome']>5000).sum()
data2 = data[(data['MonthlyIncome']<6000) & (data['Attrition']=='Yes')]
data2
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 0      41       Yes                   Sales                 1          2
# 2      37       Yes  Research & Development                 2          2
# 14     28       Yes  Research & Development                24          3
# 21     36       Yes                   Sales                 9          4
# 24     34       Yes  Research & Development                 6          1
# ...   ...       ...                     ...               ...        ...
# 1390   28       Yes  Research & Development                17          3
# 1395   31       Yes                   Sales                26          4
# 1438   23       Yes                   Sales                 9          3
# 1442   29       Yes  Research & Development                 1          4
# 1444   56       Yes  Research & Development                 7          2
#
#         EducationField  EnvironmentSatisfaction  JobSatisfaction  \
# ...

# %% [markdown]
# #Find out the distribution of employees in the education field

# %%
print(data['EducationField'].value_counts())
plt.figure(figsize=(11,6), dpi=80)
sns.histplot(data=data, x='EducationField').set_title('Attrition by Education Field');
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [markdown]
# # Explore data for Marital Status

# %%
print(data[(data['Attrition'] == 'Yes')].groupby('MaritalStatus')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5),dpi=80)
sns.countplot(data=data, x='MaritalStatus',hue='Attrition', 
              order=data['MaritalStatus'].value_counts().index, palette='seismic_r').set_title('Attrition by Marital Status');
# Out:
# MaritalStatus
# Single      120
# Married      84
# Divorced     33
# Name: Attrition, dtype: int64

# %%
print(data['MaritalStatus'].value_counts())
plt.figure(figsize=(11,6), dpi=80)
sns.histplot(data=data, x='MaritalStatus').set_title('Plot for MaritalStatus');
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
sns.set_style('darkgrid')
#sns.distplot(data['Age'], kde = True, color ='red', bins = 30)
sns.histplot(data["Age"], kde=True, color ='red', stat="density")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# Attrition by Environment Satisfaction
print(data[(data['Attrition'] == 'Yes')].groupby('DistanceFromHome')['Attrition'].count().sort_values(ascending=False))

plt.figure(figsize=(8,5),dpi=80)
sns.countplot(data=data[(data['Attrition'] == 'Yes')], x='DistanceFromHome', 
              order=data['DistanceFromHome'].value_counts().index, palette='cubehelix').set_title('Attrition by DistanceFromHome');
# Out:
# DistanceFromHome
# 2     28
# 1     26
# 9     18
# 3     14
# 24    12
# 7     11
# 10    11
# 5     10
# 8     10
# 4      9
# 6      7
# 16     7
# 22     6
# 25     6
# 12     6
# 13     6
# 23     5
# 15     5
# 17     5
# 29     5
# 20     4
# 18     4
# 14     4
# 11     4
# 19     3
# 21     3
# 26     3
# 27     3
# 28     2
# Name: Attrition, dtype: int64
